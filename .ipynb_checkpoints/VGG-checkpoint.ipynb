# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.layers import (Input, Conv2D, BatchNormalization, ZeroPadding2D,
                          MaxPooling2D, Activation, Dense, Dropout, Flatten)
from tensorflow.keras.models import Model, model_from_json
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.datasets import mnist
import os
import sys

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import pandas as pd
import seaborn as sns

# %%
def vgg16_mnist(MODEL_NAME):
    x = Input(shape = (32, 32, 1))

    y = multiConvLayer(x, 64, 2) # size 32x32
    y = multiConvLayer(y, 128, 2) # size 16x16
    y = multiConvLayer(y, 256, 3) # size 8x8
    y = multiConvLayer(y, 512, 3) # size 4x4
    y = multiConvLayer(y, 512, 3) # size 2x2
    y = Flatten()(y)
    y = Dense(units = 4096, activation='relu')(y)
    y = Dense(units = 4096, activation='relu')(y)
    y = Dense(units = 27)(y)
    y = Activation('softmax')(y)

    return Model(x, y, name = MODEL_NAME)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 194

# %%
def vgg19_mnist(MODEL_NAME):
    x = Input(shape = (32, 32, 1))

    y = multiConvLayer(x, 64, 2) # size 32x32
    y = multiConvLayer(y, 128, 2) # size 16x16
    y = multiConvLayer(y, 256, 4) # size 8x8
    y = multiConvLayer(y, 512, 4) # size 4x4
    y = multiConvLayer(y, 512, 4) # size 2x2
    y = Flatten()(y)
    y = Dense(units = 4096, activation='relu')(y)
    y = Dense(units = 4096, activation='relu')(y)
    y = Dense(units = 27)(y)
    y = Activation('softmax')(y)

    return Model(x, y, name = MODEL_NAME)

# %%
def multiConvLayer(x, value, n):
    y = x
    for _ in range(n):
        y = Conv2D(value, (3, 3), padding = 'same')(y)
        y = Activation('relu')(y)
    y = MaxPooling2D(pool_size=(2, 2), strides = (2, 2))(y)
    return y

# %%
def checkDir(modelName):
    # Used to create all necessary folders
    # Not implemented yet
    if not os.path.exists('models'):
        os.makedirs('models')
    
    # Used to save the logs
    if not os.path.exists('logs'):
        os.makedirs('logs')
        
    # Used to save the logs
    if not os.path.exists('images'):
        os.makedirs('images')
        
    if not os.path.exists('models/'+modelName):
        os.makedirs('models/'+modelName)
        
    if not os.path.exists('images/'+modelName):
        os.makedirs('images/'+modelName)

# %%
def load_mnist():
    x_train = np.load("trainX.npy")
    x_test = np.load("testX.npy")
    x_val = np.load("valX.npy")
    
    y_train = np.load("trainY.npy")
    y_test = np.load("testY.npy")
    y_val = np.load("valY.npy")
    
    x_train = x_train.reshape(-1, 32, 32, 1)
    x_test = x_test.reshape(-1, 32, 32, 1)
    x_val = x_val.reshape(-1, 32, 32, 1)
    
    y_train = to_categorical(y_train) # encode one-hot vector
    y_test = to_categorical(y_test)
    y_val = to_categorical(y_val)

    return (x_train, y_train), (x_val, y_val), (x_test, y_test)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 197

# %%
def save_model(model, modelName):
    # serialize model to JSON
    model_json = model.to_json()
    with open("models/" + modelName + "/model.json", "w") as json_file:
        json_file.write(model_json)
        
    # Save the model with best accuracy as final model
    mylist = os.listdir('models/'+modelName)
    if os.path.exists('models/' + modelName + '/' + 'model.h5'):
        os.remove('models/' + modelName + '/' + 'model.h5')
    os.rename('models/' + modelName + '/' +mylist[len(mylist)-1],'models/' + modelName + '/' + 'model.h5')
    
    mylist.remove(mylist[len(mylist)-1])
    
    while len(mylist) > 2:
        os.remove('models/' + modelName + '/' + mylist[len(mylist)-1])
        mylist.remove(mylist[len(mylist)-1])

    print("Saved model to disk")

# %%
def load_model(modelName):
    
    if os.path.isfile('models/' + modelName + '/model.json') and os.path.isfile('models/' + modelName + '/model.h5'):
        # Load json and create model
        json_file = open('models/' + modelName + '/model.json', 'r')
        loaded_model_json = json_file.read()
        json_file.close()
        loaded_model = model_from_json(loaded_model_json)
        
        # Load weights into new model
        loaded_model.load_weights('models/' + modelName + '/model.h5')

        print("Loaded model from disk")
    else:
        print ("Model does not exist. Train it first!")
    

    return loaded_model

# %%
def generatePlots(history, model, test_data, modelName):
    # Generate Training/Validation plots
    acc_MNIST = history.history['accuracy']
    val_acc_MNIST = history.history['val_accuracy']
    loss_MNIST = history.history['loss']
    val_loss_MNIST = history.history['val_loss']
    epochs_graph = range(1, len(acc_MNIST) + 1)

    plt.figure()
    plt.title('Training and Validation Accuracy', fontsize = '24')
    plt.xlabel("Epochs", fontsize = '24')
    plt.ylabel("Accuracy", fontsize = '24')
    plt.xticks(fontsize = '20')
    plt.yticks(fontsize = '20')
    plt.plot(epochs_graph, acc_MNIST, 'red', label='Training accuracy')
    plt.plot(epochs_graph, val_acc_MNIST, 'blue', label='Validation accuracy')
    plt.legend()

    plt.savefig('images/'+ modelName + '/TrainingAndValidationAcc_' + modelName + '.png')

    plt.figure()
    plt.title('Training and Validation Loss', fontsize = '24')
    plt.xticks(fontsize = '20')
    plt.yticks(fontsize = '20')
    plt.xlabel("Epochs", fontsize = '24')
    plt.ylabel("Loss", fontsize = '24')
    plt.plot(epochs_graph, loss_MNIST, 'red', label='Training loss')
    plt.plot(epochs_graph, val_loss_MNIST, 'blue', label='Validation loss')
    plt.legend()

    plt.savefig('images/'+ modelName + '/TrainingAndValidationLoss_' + modelName + '.png')
    plt.show()

    Y_pred_MNIST = model.predict(test_data[0])
    Y_pred_classes_MNIST = np.argmax(Y_pred_MNIST, axis = 1) 
    Y_truth_MNIST = np.argmax(test_data[1], axis = 1) 

    confusion_mtx_MNIST = confusion_matrix(Y_truth_MNIST, Y_pred_classes_MNIST)

    f, ax = plt.subplots(figsize=(16, 10))
    sns.heatmap(confusion_mtx_MNIST, annot=True, linewidths=0.01, cmap="viridis", linecolor="gray", fmt= '.1f', ax = ax)
    plt.xlabel("Predicted Label", fontsize = 24)
    plt.ylabel("True Label", fontsize = 24)
    plt.xticks(fontsize = '20')
    plt.yticks(fontsize = '20')
    plt.title("Confusion Matrix", fontsize = '24')

    plt.savefig('images/'+ modelName + '/ConfusionMatrix_' + modelName + '.png')
    plt.show()

# %%
def display_errors(errors_index, img_errors, pred_errors, obs_errors, x, y, nrows, ncols):
    n = 0
    nrows = nrows
    ncols = ncols
    fig, ax = plt.subplots(nrows, ncols, sharex=True, sharey=True, figsize=(10, 10))
    plt.subplots_adjust(wspace=0.5, hspace=0.5)
    
    for row in range(nrows):
        for col in range(ncols):
            error = errors_index[n]
            ax[row, col].imshow((img_errors[error]).reshape((x, y)),  cmap = "gray")
            ax[row, col].set_title("Predicted label: {}\nTrue label: {}".format(pred_errors[error], obs_errors[error]))
            ax[row, col].set_xticks([])
            ax[row, col].set_yticks([])
            ax[row, col].set_xticklabels([])
            ax[row, col].set_yticklabels([])
            n += 1

# %%
def badPredictionsMNIST(model, testData):
    Y_pred_MNIST = model.predict(testData[0])
    Y_pred_classes_MNIST = np.argmax(Y_pred_MNIST, axis = 1) 
    Y_truth_MNIST = np.argmax(testData[1], axis = 1) 
    
    np.sum(Y_truth_MNIST == Y_pred_classes_MNIST) / len(Y_truth_MNIST)
    
    errors_MNIST = (Y_pred_classes_MNIST - Y_truth_MNIST != 0)

    Y_pred_classes_errors_MNIST = Y_pred_classes_MNIST[errors_MNIST]
    Y_pred_errors_MNIST = Y_pred_MNIST[errors_MNIST]
    Y_true_errors_MNIST = Y_truth_MNIST[errors_MNIST]
    X_test_errors_MNIST = testData[0][errors_MNIST]


    Y_pred_errors_prob_MNIST = np.max(Y_pred_errors_MNIST, axis = 1)
    True_prob_errors_MNIST = np.diagonal(np.take(Y_pred_errors_MNIST, Y_true_errors_MNIST, axis=1))
    Delta_pred_true_errors_MNIST = Y_pred_errors_prob_MNIST - True_prob_errors_MNIST
    Sorted_dela_errors_MNIST = np.argsort(Delta_pred_true_errors_MNIST)
    Most_important_errors_MNIST = Sorted_dela_errors_MNIST[-16:]
    
    display_errors(Most_important_errors_MNIST, X_test_errors_MNIST, Y_pred_classes_errors_MNIST, Y_true_errors_MNIST, 28, 28, 4, 4)

# %%
def main(arg):
    # Define Adam Optimizer
    adam = Adam(lr=1e-4, decay=1e-6)
    
    tensorboard = TensorBoard(write_grads=True, write_images=True)
    
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # dimesion reduction
        rotation_range=5,  # randomly rotate images in the range 5 degrees
        zoom_range = 0.1, # Randomly zoom image 10%
        width_shift_range=0.1,  # randomly shift images horizontally 10%
        height_shift_range=0.1,  # randomly shift images vertically 10%
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images
       
    if arg == "vgg16-train-mnist":
        
        MODEL_NAME = "VGG16-MNIST"
        
        # Load dataset
        training_data, val_data, test_data = load_mnist()
        
        # Create directories
        checkDir(MODEL_NAME)
        
        # Save best model based on validation accuracy
        chkpoint = ModelCheckpoint("models/" + MODEL_NAME +"/weights.{epoch:02d}-{val_accuracy:.4f}.hdf5", save_best_only=True, monitor='val_accuracy', mode='max')
        
        # Create the model architecture
        model = vgg16_mnist(MODEL_NAME)
        
        # Compile the model
        model.compile(adam, 'categorical_crossentropy', metrics=['accuracy'])

        datagen.fit(training_data[0])

        batch_size = 25
        history = model.fit(datagen.flow(training_data[0], training_data[1], batch_size = batch_size), epochs=50, validation_data=(val_data[0], val_data[1]), steps_per_epoch = training_data[0].shape[0] // batch_size, callbacks = [tensorboard, chkpoint])

        generatePlots(history, model, test_data, MODEL_NAME)
        save_model(model, MODEL_NAME)
        
    elif arg == "vgg19-train-mnist":
        
        MODEL_NAME = "VGG19-MNIST"
        
        # Load dataset
        training_data, val_data, test_data = load_mnist()
        
        # Create directories
        checkDir(MODEL_NAME)
        
        # Save best model based on validation accuracy
        chkpoint = ModelCheckpoint("models/" + MODEL_NAME +"/weights.{epoch:02d}-{val_accuracy:.4f}.hdf5", save_best_only=True, monitor='val_accuracy', mode='max')
        
        # Create the model architecture
        model = vgg19_mnist(MODEL_NAME)
        
        # Compile the model
        model.compile(adam, 'categorical_crossentropy', metrics=['accuracy'])

        datagen.fit(training_data[0])

        batch_size = 25
        history = model.fit(datagen.flow(training_data[0], training_data[1], batch_size = batch_size), epochs=50, validation_data=(val_data[0], val_data[1]), steps_per_epoch = training_data[0].shape[0] // batch_size, callbacks = [tensorboard, chkpoint])

        generatePlots(history, model, test_data, MODEL_NAME)
        save_model(model, MODEL_NAME)
        

        
    elif arg == "test-vgg16-mnist":
        
        MODEL_NAME = "VGG16-MNIST"
        
        # Load the model
        model = load_model(MODEL_NAME)
        
        # Load dataset
        training_data, val_data, test_data = load_mnist()
        
        # Compile the model
        model.compile(adam, 'categorical_crossentropy', metrics=['accuracy'])
        
        # Get score
        score = model.evaluate(test_data[0], test_data[1], verbose=0)
        print(score)
        
        badPredictionsMNIST(model, test_data)
        

        
    elif arg == "test-vgg19-mnist":
        
        MODEL_NAME = "VGG19-MNIST"
        
        # Load the model
        model = load_model(MODEL_NAME)
        
        # Load dataset
        training_data, val_data, test_data = load_mnist()
        
        # Compile the model
        model.compile(adam, 'categorical_crossentropy', metrics=['accuracy'])
        
        # Get score
        score = model.evaluate(test_data[0], test_data[1], verbose=0)
        print(score)
        
        badPredictionsMNIST(model, test_data)
        
    else:
        print("Invalid argument")
        sys.exit()

# %%
# Train VGG16 on MNIST dataset
main("vgg16-train-mnist")
# Out:
# WARNING:tensorflow:`write_grads` will be ignored in TensorFlow 2.0 for the `TensorBoard` Callback.
# WARNING:tensorflow:`write_grads` will be ignored in TensorFlow 2.0 for the `TensorBoard` Callback.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 15149 steps, validate on 19934 samples
# Epoch 1/50
# 15149/15149 [==============================] - 485s 32ms/step - loss: 0.4020 - accuracy: 0.8741 - val_loss: 12.1567 - val_accuracy: 0.4463
# Epoch 2/50
# 15149/15149 [==============================] - 490s 32ms/step - loss: 0.1371 - accuracy: 0.9569 - val_loss: 12.0974 - val_accuracy: 0.4514
# Epoch 3/50
# 15149/15149 [==============================] - 491s 32ms/step - loss: 0.0925 - accuracy: 0.9715 - val_loss: 12.0874 - val_accuracy: 0.4495
# Epoch 4/50
# 15149/15149 [==============================] - 497s 33ms/step - loss: 0.0713 - accuracy: 0.9783 - val_loss: 12.3932 - val_accuracy: 0.4524
# Epoch 5/50
# 15149/15149 [==============================] - 483s 32ms/step - loss: 0.0635 - accuracy: 0.9826 - val_loss: 16.4540 - val_accuracy: 0.4516
# Epoch 6/50
# 15149/15149 [==============================] - 473s 31ms/step - loss: 0.0497 - accuracy: 0.9855 - val_loss: 17.2990 - val_accuracy: 0.4497
# Epoch 7/50
# 15149/15149 [==============================] - 468s 31ms/step - loss: 0.0451 - accuracy: 0.9874 - val_loss: 14.9434 - val_accuracy: 0.4508
# Epoch 8/50
# 15149/15149 [==============================] - 470s 31ms/step - loss: 0.0399 - accuracy: 0.9894 - val_loss: 15.8156 - val_accuracy: 0.4528
# Epoch 9/50
# 15149/15149 [==============================] - 470s 31ms/step - loss: 0.0327 - accuracy: 0.9909 - val_loss: 15.5309 - val_accuracy: 0.4536
# Epoch 10/50
# 15149/15149 [==============================] - 446s 29ms/step - loss: 0.0196 - accuracy: 0.9963 - val_loss: 132.4370 - val_accuracy: 0.4545
# Epoch 30/50
# 15149/15149 [==============================] - 446s 29ms/step - loss: 0.0169 - accuracy: 0.9964 - val_loss: 40.3391 - val_accuracy: 0.4541
# Epoch 31/50
# 15149/15149 [==============================] - 447s 30ms/step - loss: 0.0164 - accuracy: 0.9964 - val_loss: 86.3195 - val_accuracy: 0.4546
# Epoch 32/50
# 15149/15149 [==============================] - 446s 29ms/step - loss: 0.0216 - accuracy: 0.9959 - val_loss: 92.1705 - val_accuracy: 0.4542
# Epoch 33/50
# 15149/15149 [==============================] - 446s 29ms/step - loss: 0.0161 - accuracy: 0.9966 - val_loss: 64.5521 - val_accuracy: 0.4539
# Epoch 34/50
# 15149/15149 [==============================] - 445s 29ms/step - loss: 0.0167 - accuracy: 0.9963 - val_loss: 116.0816 - val_accuracy: 0.4542
# Epoch 35/50
# 15149/15149 [==============================] - 445s 29ms/step - loss: 0.0153 - accuracy: 0.9966 - val_loss: 191.7083 - val_accuracy: 0.4544
# Epoch 36/50
# 15149/15149 [==============================] - 26469s 2s/step - loss: 0.0976 - accuracy: 0.9962 - val_loss: 60.6141 - val_accuracy: 0.4542
# Epoch 37/50
# 15149/15149 [==============================] - 475s 31ms/step - loss: 0.0146 - accuracy: 0.9970 - val_loss: 405.0270 - val_accuracy: 0.4542
# Epoch 38/50
# 15149/15149 [==============================] - 483s 32ms/step - loss: 0.0158 - accuracy: 0.9967 - val_loss: 41.6125 - val_accuracy: 0.4533
# Epoch 39/50
# 15149/15149 [==============================] - 472s 31ms/step - loss: 0.0143 - accuracy: 0.9969 - val_loss: 69.6164 - val_accuracy: 0.4519
# Epoch 40/50
# 15149/15149 [==============================] - 468s 31ms/step - loss: 0.0139 - accuracy: 0.9971 - val_loss: 65.6479 - val_accuracy: 0.4538
# Epoch 41/50
# 11399/15149 [=====================>........] - ETA: 1:51 - loss: 0.0140 - accuracy: 0.9970
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py", line 767, in on_epoch
#     yield epoch_logs
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py", line 342, in fit
#     total_epochs=epochs)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py", line 128, in run_one_epoch
#     batch_outs = execution_function(iterator)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py", line 98, in execution_function
#     distributed_function(input_fn))
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\util\nest.py", line 568, in map_structure
#     structure[0], [func(*x) for x in entries],
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\util\nest.py", line 568, in <listcomp>
#     structure[0], [func(*x) for x in entries],
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py", line 130, in _non_none_constant_value
#     constant_value = tensor_util.constant_value(v)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\framework\tensor_util.py", line 822, in constant_value
#     return tensor.numpy()
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\framework\ops.py", line 942, in numpy
#     maybe_arr = self._numpy()  # pylint: disable=protected-access
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\framework\ops.py", line 908, in _numpy
#     return self._numpy_internal()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-29-47a2065f1d33>", line 2, in <module>
#     main("vgg16-train-mnist")
#   File "<ipython-input-22-d390a06d6f11>", line 42, in main
#     history = model.fit(datagen.flow(training_data[0], training_data[1], batch_size = batch_size), epochs=50, validation_data=(val_data[0], val_data[1]), steps_per_epoch = training_data[0].shape[0] // batch_size, callbacks = [tensorboard, chkpoint])
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\engine\training.py", line 819, in fit
#     use_multiprocessing=use_multiprocessing)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py", line 397, in fit
#     prefix='val_')
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\contextlib.py", line 130, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py", line 771, in on_epoch
#     self.callbacks.on_epoch_end(epoch, epoch_logs)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\callbacks.py", line 302, in on_epoch_end
#     callback.on_epoch_end(epoch, logs)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\callbacks.py", line 992, in on_epoch_end
#     self._save_model(epoch=epoch, logs=logs)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\callbacks.py", line 1011, in _save_model
#     filepath = self._get_file_path(epoch, logs)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\callbacks.py", line 1055, in _get_file_path
#     return self.filepath.format(epoch=epoch + 1, **logs)
# KeyError: 'val_accuracy'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\inspect.py", line 1495, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\inspect.py", line 1453, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py", line 767, in on_epoch
#     yield epoch_logs
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py", line 342, in fit
#     total_epochs=epochs)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py", line 128, in run_one_epoch
#     batch_outs = execution_function(iterator)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py", line 98, in execution_function
#     distributed_function(input_fn))
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\util\nest.py", line 568, in map_structure
#     structure[0], [func(*x) for x in entries],
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\util\nest.py", line 568, in <listcomp>
#     structure[0], [func(*x) for x in entries],
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py", line 130, in _non_none_constant_value
#     constant_value = tensor_util.constant_value(v)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\framework\tensor_util.py", line 822, in constant_value
#     return tensor.numpy()
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\framework\ops.py", line 942, in numpy
#     maybe_arr = self._numpy()  # pylint: disable=protected-access
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\framework\ops.py", line 908, in _numpy
#     return self._numpy_internal()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-29-47a2065f1d33>", line 2, in <module>
#     main("vgg16-train-mnist")
#   File "<ipython-input-22-d390a06d6f11>", line 42, in main
#     history = model.fit(datagen.flow(training_data[0], training_data[1], batch_size = batch_size), epochs=50, validation_data=(val_data[0], val_data[1]), steps_per_epoch = training_data[0].shape[0] // batch_size, callbacks = [tensorboard, chkpoint])
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\engine\training.py", line 819, in fit
#     use_multiprocessing=use_multiprocessing)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py", line 397, in fit
#     prefix='val_')
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\contextlib.py", line 130, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py", line 771, in on_epoch
#     self.callbacks.on_epoch_end(epoch, epoch_logs)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\callbacks.py", line 302, in on_epoch_end
#     callback.on_epoch_end(epoch, logs)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\callbacks.py", line 992, in on_epoch_end
#     self._save_model(epoch=epoch, logs=logs)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\callbacks.py", line 1011, in _save_model
#     filepath = self._get_file_path(epoch, logs)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\callbacks.py", line 1055, in _get_file_path
#     return self.filepath.format(epoch=epoch + 1, **logs)
# KeyError: 'val_accuracy'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 3454, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\inspect.py", line 1495, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\inspect.py", line 1453, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py", line 767, in on_epoch
#     yield epoch_logs
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py", line 342, in fit
#     total_epochs=epochs)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py", line 128, in run_one_epoch
#     batch_outs = execution_function(iterator)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py", line 98, in execution_function
#     distributed_function(input_fn))
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\util\nest.py", line 568, in map_structure
#     structure[0], [func(*x) for x in entries],
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\util\nest.py", line 568, in <listcomp>
#     structure[0], [func(*x) for x in entries],
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py", line 130, in _non_none_constant_value
#     constant_value = tensor_util.constant_value(v)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\framework\tensor_util.py", line 822, in constant_value
#     return tensor.numpy()
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\framework\ops.py", line 942, in numpy
#     maybe_arr = self._numpy()  # pylint: disable=protected-access
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\framework\ops.py", line 908, in _numpy
#     return self._numpy_internal()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-29-47a2065f1d33>", line 2, in <module>
#     main("vgg16-train-mnist")
#   File "<ipython-input-22-d390a06d6f11>", line 42, in main
#     history = model.fit(datagen.flow(training_data[0], training_data[1], batch_size = batch_size), epochs=50, validation_data=(val_data[0], val_data[1]), steps_per_epoch = training_data[0].shape[0] // batch_size, callbacks = [tensorboard, chkpoint])
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\engine\training.py", line 819, in fit
#     use_multiprocessing=use_multiprocessing)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py", line 397, in fit
#     prefix='val_')
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\contextlib.py", line 130, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py", line 771, in on_epoch
#     self.callbacks.on_epoch_end(epoch, epoch_logs)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\callbacks.py", line 302, in on_epoch_end
#     callback.on_epoch_end(epoch, logs)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\callbacks.py", line 992, in on_epoch_end
#     self._save_model(epoch=epoch, logs=logs)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\callbacks.py", line 1011, in _save_model
#     filepath = self._get_file_path(epoch, logs)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow_core\python\keras\callbacks.py", line 1055, in _get_file_path
#     return self.filepath.format(epoch=epoch + 1, **logs)
# KeyError: 'val_accuracy'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 3454, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 3166, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 3376, in run_ast_nodes
#     self.showtraceback()
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\inspect.py", line 1495, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\inspect.py", line 1453, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\Roger\anaconda3\envs\ml\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'

# %%
# Test VGG16 on MNIST dataset
main("test-vgg16-mnist")
# Out:
# WARNING:tensorflow:`write_grads` will be ignored in TensorFlow 2.0 for the `TensorBoard` Callback.
# Loaded model from disk
# [0.04633294346585395, 0.9953]

# %%
# Train VGG19 on Digits dataset
main("vgg19-train-digits")
# Out:
# WARNING:tensorflow:`write_grads` will be ignored in TensorFlow 2.0 for the `TensorBoard` Callback.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 51 steps, validate on 320 samples
# Epoch 1/50
# 51/51 [==============================] - 5s 99ms/step - loss: 2.3030 - accuracy: 0.0829 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 2/50
# 51/51 [==============================] - 4s 82ms/step - loss: 2.1717 - accuracy: 0.1371 - val_loss: 1.9879 - val_accuracy: 0.1875
# Epoch 3/50
# 51/51 [==============================] - 6s 118ms/step - loss: 1.8990 - accuracy: 0.1960 - val_loss: 1.7639 - val_accuracy: 0.2000
# Epoch 4/50
# 51/51 [==============================] - 5s 101ms/step - loss: 1.6608 - accuracy: 0.2733 - val_loss: 1.5709 - val_accuracy: 0.2875
# Epoch 5/50
# 51/51 [==============================] - 7s 139ms/step - loss: 1.4643 - accuracy: 0.3211 - val_loss: 1.4710 - val_accuracy: 0.3094
# Epoch 6/50
# 51/51 [==============================] - 2s 46ms/step - loss: 1.3679 - accuracy: 0.3633 - val_loss: 1.5766 - val_accuracy: 0.2969
# Epoch 7/50
# 51/51 [==============================] - 4s 84ms/step - loss: 1.3588 - accuracy: 0.3562 - val_loss: 1.2161 - val_accuracy: 0.4437
# Epoch 8/50
# 51/51 [==============================] - 6s 126ms/step - loss: 1.1946 - accuracy: 0.4319 - val_loss: 1.0135 - val_accuracy: 0.5219
# Epoch 9/50
# 51/51 [==============================] - 5s 104ms/step - loss: 0.9857 - accuracy: 0.5673 - val_loss: 0.9400 - val_accuracy: 0.5688
# Epoch 10/50
# 51/51 [==============================] - 6s 110ms/step - loss: 0.8895 - accuracy: 0.6327 - val_loss: 0.8662 - val_accuracy: 0.5813
# Epoch 11/50
# 51/51 [==============================] - 8s 147ms/step - loss: 0.7581 - accuracy: 0.6821 - val_loss: 0.5973 - val_accuracy: 0.7344
# Epoch 12/50
# 51/51 [==============================] - 5s 95ms/step - loss: 0.6854 - accuracy: 0.7243 - val_loss: 0.6392 - val_accuracy: 0.8062
# Epoch 13/50
# 51/51 [==============================] - 6s 117ms/step - loss: 0.6282 - accuracy: 0.7554 - val_loss: 0.4917 - val_accuracy: 0.8344

# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-40-6be3b8ad414f> in <module>
#       1 # Test VGG19 on Digits Dataset
# ----> 2 main("test-vgg19-digits")
#
# <ipython-input-31-988ab271e7d8> in main(arg)
#     181         print(score)
#     182
# --> 183         badPredictionsDigits(model, test_data)
#     184
#     185     elif arg == "test-vgg19-mnist":
#
# <ipython-input-38-eb88cd26a5c2> in badPredictionsDigits(model, testData)
#      17     Most_important_errors_Digits = Sorted_dela_errors_Digits[-16:]
#      18
# ---> 19     display_errors(Most_important_errors_Digits, X_test_errors_Digits, Y_pred_classes_errors_Digits, Y_true_errors_Digits, 16, 15, 2, 4)
#
# <ipython-input-14-af6ff99a91f7> in display_errors(errors_index, img_errors, pred_errors, obs_errors, x, y, nrows, ncols)
#       8     for row in range(nrows):
#       9         for col in range(ncols):
# ---> 10             error = errors_index[n]
#      11             ax[row, col].imshow((img_errors[error]).reshape((x, y)),  cmap = "gray")
#      12             ax[row, col].set_title("Predicted label: {}\nTrue label: {}".format(pred_errors[error], obs_errors[error]))
#
# IndexError: index 5 is out of bounds for axis 0 with size 5

# %%
# Train VGG19 on MNIST dataset
main("vgg19-train-mnist")
# Out:
# WARNING:tensorflow:`write_grads` will be ignored in TensorFlow 2.0 for the `TensorBoard` Callback.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 2000 steps, validate on 10000 samples
# Epoch 1/50
# 2000/2000 [==============================] - 83s 42ms/step - loss: 0.4753 - accuracy: 0.8317 - val_loss: 0.0834 - val_accuracy: 0.9797
# Epoch 2/50
# 2000/2000 [==============================] - 84s 42ms/step - loss: 0.1165 - accuracy: 0.9728 - val_loss: 0.0582 - val_accuracy: 0.9872
# Epoch 3/50
# 2000/2000 [==============================] - 85s 42ms/step - loss: 0.0919 - accuracy: 0.9791 - val_loss: 0.0466 - val_accuracy: 0.9909
# Epoch 4/50
# 2000/2000 [==============================] - 82s 41ms/step - loss: 0.0748 - accuracy: 0.9839 - val_loss: 0.0617 - val_accuracy: 0.9869
# Epoch 5/50
# 2000/2000 [==============================] - 80s 40ms/step - loss: 0.0710 - accuracy: 0.9844 - val_loss: 0.0833 - val_accuracy: 0.9840
# Epoch 6/50
# 2000/2000 [==============================] - 81s 40ms/step - loss: 0.0569 - accuracy: 0.9876 - val_loss: 0.0385 - val_accuracy: 0.9928
# Epoch 7/50
# 2000/2000 [==============================] - 83s 42ms/step - loss: 0.0605 - accuracy: 0.9868 - val_loss: 0.2712 - val_accuracy: 0.9439
# Epoch 8/50
# 2000/2000 [==============================] - 82s 41ms/step - loss: 0.0553 - accuracy: 0.9881 - val_loss: 0.0397 - val_accuracy: 0.9911
# Epoch 9/50
# 2000/2000 [==============================] - 81s 40ms/step - loss: 0.0466 - accuracy: 0.9894 - val_loss: 0.0474 - val_accuracy: 0.9903
# Epoch 10/50
# 2000/2000 [==============================] - 80s 40ms/step - loss: 0.0473 - accuracy: 0.9897 - val_loss: 0.0384 - val_accuracy: 0.9927
# Epoch 11/50
# 2000/2000 [==============================] - 80s 40ms/step - loss: 0.0443 - accuracy: 0.9904 - val_loss: 0.0439 - val_accuracy: 0.9899
# Epoch 12/50
# 2000/2000 [==============================] - 80s 40ms/step - loss: 0.0400 - accuracy: 0.9915 - val_loss: 0.0455 - val_accuracy: 0.9923
# Epoch 13/50
# 2000/2000 [==============================] - 82s 41ms/step - loss: 0.0432 - accuracy: 0.9907 - val_loss: 0.0345 - val_accuracy: 0.9929
# Epoch 33/50
# 2000/2000 [==============================] - 82s 41ms/step - loss: 0.0230 - accuracy: 0.9950 - val_loss: 0.0614 - val_accuracy: 0.9905
# Epoch 34/50
# 2000/2000 [==============================] - 82s 41ms/step - loss: 0.0230 - accuracy: 0.9950 - val_loss: 0.0354 - val_accuracy: 0.9933
# Epoch 35/50
# 2000/2000 [==============================] - 81s 40ms/step - loss: 0.0305 - accuracy: 0.9950 - val_loss: 0.0341 - val_accuracy: 0.9942
# Epoch 36/50
# 2000/2000 [==============================] - 82s 41ms/step - loss: 0.0216 - accuracy: 0.9953 - val_loss: 0.0612 - val_accuracy: 0.9938
# Epoch 37/50
# 2000/2000 [==============================] - 83s 41ms/step - loss: 0.0159 - accuracy: 0.9964 - val_loss: 0.0560 - val_accuracy: 0.9925
# Epoch 38/50
# 2000/2000 [==============================] - 86s 43ms/step - loss: 0.0269 - accuracy: 0.9944 - val_loss: 0.0367 - val_accuracy: 0.9937
# Epoch 39/50
# 2000/2000 [==============================] - 83s 41ms/step - loss: 0.0211 - accuracy: 0.9956 - val_loss: 0.0419 - val_accuracy: 0.9937
# Epoch 40/50
# 2000/2000 [==============================] - 80s 40ms/step - loss: 0.0219 - accuracy: 0.9958 - val_loss: 0.0444 - val_accuracy: 0.9948
# Epoch 41/50
# 2000/2000 [==============================] - 79s 39ms/step - loss: 0.0192 - accuracy: 0.9958 - val_loss: 0.0322 - val_accuracy: 0.9947
# Epoch 42/50
# 2000/2000 [==============================] - 80s 40ms/step - loss: 0.0146 - accuracy: 0.9968 - val_loss: 0.0734 - val_accuracy: 0.9937
# Epoch 43/50
# 2000/2000 [==============================] - 80s 40ms/step - loss: 0.0178 - accuracy: 0.9963 - val_loss: 0.0376 - val_accuracy: 0.9939
# Epoch 44/50
# 2000/2000 [==============================] - 80s 40ms/step - loss: 0.0193 - accuracy: 0.9962 - val_loss: 0.0515 - val_accuracy: 0.9918
# Epoch 45/50
# 2000/2000 [==============================] - 80s 40ms/step - loss: 0.0193 - accuracy: 0.9959 - val_loss: 0.0407 - val_accuracy: 0.9947
# Epoch 46/50
# 2000/2000 [==============================] - 80s 40ms/step - loss: 0.0181 - accuracy: 0.9960 - val_loss: 0.0408 - val_accuracy: 0.9930
# Epoch 47/50
# 2000/2000 [==============================] - 80s 40ms/step - loss: 0.0213 - accuracy: 0.9956 - val_loss: 0.0472 - val_accuracy: 0.9942
# Epoch 48/50
# 2000/2000 [==============================] - 80s 40ms/step - loss: 0.0188 - accuracy: 0.9962 - val_loss: 0.0271 - val_accuracy: 0.9946
# Epoch 49/50
# 2000/2000 [==============================] - 80s 40ms/step - loss: 0.0147 - accuracy: 0.9968 - val_loss: 0.0544 - val_accuracy: 0.9923
# Epoch 50/50
# 2000/2000 [==============================] - 82s 41ms/step - loss: 0.0189 - accuracy: 0.9960 - val_loss: 0.0405 - val_accuracy: 0.9954
# Saved model to disk

# %%
# Test VGG19 on MNIST Dataset
main("test-vgg19-mnist")
# Out:
# WARNING:tensorflow:`write_grads` will be ignored in TensorFlow 2.0 for the `TensorBoard` Callback.
# Loaded model from disk
# [0.030038597204554623, 0.9948]
